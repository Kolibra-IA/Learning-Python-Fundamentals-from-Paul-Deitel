# %% [markdown]
# # Single- and Double-Quoted Exercise

# %% [markdown]
# ### 1

# %% [markdown]
# Write an expression that displays the type of 'word'.

# %%
type('word')

# %% [markdown]
# ### 2

# %% [raw]
# What does the following print statement display:
#
# print('int(5.2)', 'truncates 5.2 to', int(5.2))

# %%
print('int(5.2)', 'truncates 5.2 to', int(5.2))
# Out:
# int(5.2) truncates 5.2 to 5
