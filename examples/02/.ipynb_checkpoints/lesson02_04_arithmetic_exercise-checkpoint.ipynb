# %% [markdown]
# # Arithmetic Exercise

# %% [markdown]
# Evaluate the expression 3*(4-5) with and without parentheses. Are the parentheses redundant?

# %%
x = 3*(4-5);

x
# Out:
# -3

# %%
x = 3*4-5;

x
# Out:
# 7

# %% [markdown]
# Evaluate the expresions 4 exp 3 exp 2, (4 exp 3) exp 2 and 4 exp (3 exp 2). Is any of the parentheses redundant?

# %% [markdown]
# ### 1

# %%
x = 4**3**2;

x
# Out:
# 262144

# %% [markdown]
# ### 2

# %%
x = (4**3) ** 2;

x
# Out:
# 4096

# %% [markdown]
# ### 3

# %%
x = 4**(3**2);

x
# Out:
# 262144

# %% [markdown]
# ##### Is any of the parentheses redundant?

# %% [markdown]
# Yes, the parentheses in the third question are redundant.
