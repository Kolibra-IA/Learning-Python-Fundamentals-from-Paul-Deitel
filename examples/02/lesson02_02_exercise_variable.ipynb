# %% [markdown]
# # LESSON 2'S EXECISE : VARIABLE

# %% [markdown]
# ##### Calculate the sum of 10.8, 12.2 and 0.2; store it in the variable total; then, display total's value and its type

# %%
total = 10.8 + 12.2 + 0.2;

print(total);
# Out:
# 23.2

# %%
type(total)
# Out:
# float
